# %% [markdown]
# <a href="https://colab.research.google.com/github/senBenz/ML/blob/python_practices/Exercice4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = [5.1, 3.5, 1.4, 0.2]
x2 = [4.9, 3.0, 1.4, 0.2]
x3 = [6.2, 2.9, 4.3, 1.3]
x4 = [5.9, 3.0, 4.2, 1.5]
x5 = [6.7, 3.1, 5.6, 2.4]
a = [1,0,0,1,1,0,1,0]
b = [0,1,0,1,0,1,1,0]

# %%
y=[]
x=[]
list_of_values=[]

import math

def dist_euclid(x_vec, y_vec):
  sum_sq_diff = 0
  for j, k in zip(x_vec, y_vec):
    sum_sq_diff =+ (j - k)**2
    list_of_values.append(sum_sq_diff)
  return list_of_values

print(dist_euclid(x1,x2))
# Out:
# [0.039999999999999716, 0.25, 0.0, 0.0]
