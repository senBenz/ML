# %% [markdown]
# <a href="https://colab.research.google.com/github/senBenz/ML/blob/python_practices/SAAD_AAQIL_Exercice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercice 1 :

# %%
L1 = [2, 5, 7, 9, 10, 5, 15, 2, 18, 49, 17, 4,]
L2 = []

for i in L1:
    i=i**2
    L2.append(i)
#print(L2)

D=dict(zip(L1,L2))
#print(D)

# %% [markdown]
# Si une clé apparaît plusieurs fois dans L1, quelle
# valeur restera dans D ?
#
#
#
#
#
# > Si une Cle apparait plusieurs fois dans L1 on va avoir qu'un seul car on peut pas avoir un cle avec plusieurs valeur differentes

# %%
#1) premiere methode
#L2 = [4, 25, 49, 81, 100, 25, 225, 4, 324, 2401, 289, 16]

#L1.append(L2)

# %%
#2) deuxieme methode
L1.extend(L2)
#print(L1)
# Out:
# [2, 5, 7, 9, 10, 5, 15, 2, 18, 49, 17, 4, 4, 25, 49, 81, 100, 25, 225, 4, 324, 2401, 289, 16]

# %%
S1=set(L1)
print(S1)
# Out:
# {225, 2, 2401, 4, 5, 100, 7, 324, 9, 10, 15, 289, 49, 18, 17, 81, 16, 25}

# %% [markdown]
# Expliquez ce qui arrive aux doublons et
# à l’ordre lors de cette transformation.
#
#
# > Lors de la transofrmation d'une liste a un set on peut voir que les doublons seront ignorees car un set ne peut pas contenir des doublons

# %%
S2=[]
for x in S1:
  if x%2==0:
   S2.append(x)
print(S1)
# Out:
# {225, 2401, 5, 7, 324, 9, 10, 15, 289, 49, 18, 17, 81, 16, 25}

# %%
print(D.keys(),S1)

# %%
l3=[]
for d in D.keys():
  if d  in S1 :
    l3.append(d)

for l in l3:
  if l in D.keys():
    del D[l]
print(D.keys())
# Out:
# dict_keys([2, 4])

# %%
nombre_elemnt=0
for n in S1:
  if n in S1:
    nombre_elemnt=nombre_elemnt+1
print(nombre_elemnt)
D.update({nombre_elemnt:"S1"})
print(D)
# Out:
# 15
# {2: 4, 4: 16, 15: 'S1'}
